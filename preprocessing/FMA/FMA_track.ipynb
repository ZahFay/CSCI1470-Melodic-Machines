# %%
import os
import numpy as np
import pandas as pd
import sklearn.utils
import utils
import IPython.display as ipd

# %% [markdown]
# # Get track ids

# %%
artists = pd.read_csv('../MSD_FMA_artists.csv')['name'].values

# %%
tracks = utils.load('../../../tracks.csv')

# %%
ipd.display(tracks['artist'].head(100))
# Out:
#          active_year_begin active_year_end  \
# track_id
# 2               2006-01-01             NaT
# 3               2006-01-01             NaT
# 5               2006-01-01             NaT
# 10                     NaT             NaT
# 20              1990-01-01      2011-01-01
# ...                    ...             ...
# 251                    NaT             NaT
# 252                    NaT             NaT
# 253                    NaT             NaT
# 254                    NaT             NaT
# 255                    NaT             NaT
#
#                                           associated_labels  \
# track_id
# 2                                                       NaN
# 3                                                       NaN
# 5                                                       NaN
# 10        Mexican Summer, Richie Records, Woodsist, Skul...
# 20                                                      NaN
# ...

# %%
filtered_track_ids = tracks[tracks[('artist', 'name')].str.lower().isin(artists)].index
filtered_track_ids
# Out:
# Index([    10,    156,    157,    158,    159,    160,    161,    162,    163,
#           164,
#        ...
#        154420, 154421, 154422, 154774, 154835, 154836, 154837, 155000, 155031,
#        155056],
#       dtype='int64', name='track_id', length=7199)

# %%
tracks.loc[tracks[('track', 'title')] == 'BangBang', ('track')]
# Out:
#           bit_rate  comments composer        date_created date_recorded  \
# track_id
# 80295       192000         0      NaN 2013-03-14 01:02:30           NaT
#
#           duration  favorites genre_top genres genres_all information  \
# track_id
# 80295          142          0   Hip-Hop   [21]       [21]         NaN
#
#           interest language_code  \
# track_id
# 80295         1319           NaN
#
#                                                     license  listens lyricist  \
# track_id
# 80295     Attribution-Noncommercial-Share Alike 3.0 Unit...      715      NaN
#
#           number publisher tags     title
# track_id
# 80295          5       NaN   []  BangBang

# %%
tracks[('track', 'title')]

# %% [markdown]
# # Get audios

# %%
fma = utils.FreeMusicArchive(os.environ.get('FMA_KEY'))

# %%
track_file = fma.get_track(10, 'track_file')
fma.download_track(track_file, path='track.mp3')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 track_file = fma.get_track(10, 'track_file')
#       2 fma.download_track(track_file, path='track.mp3')
#
# File c:\Users\hsnutardis\OneDrive - Brown University\Brown\Spring 2025\CSCI 1470\Final Project\CSCI1470-Melodic-Machines\preprocessing\FMA\utils.py:67, in FreeMusicArchive.get_track(self, track_id, fields)
#      66 def get_track(self, track_id, fields=None):
# ---> 67     return self._get_data('track', track_id, fields)
#
# File c:\Users\hsnutardis\OneDrive - Brown University\Brown\Spring 2025\CSCI 1470\Final Project\CSCI1470-Melodic-Machines\preprocessing\FMA\utils.py:45, in FreeMusicArchive._get_data(self, dataset, fma_id, fields)
#      43 def _get_data(self, dataset, fma_id, fields=None):
#      44     url = self.BASE_URL + dataset + 's.json?'
# ...
